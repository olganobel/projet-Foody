# %%
from sqlalchemy import create_engine
import mysql.connector as mysqlConnector
import pandas as pd
con = create_engine('mysql+mysqldb://root:devdata@20@localhost/foody', echo = False) 
con.connect()

print(con)
# Out:
# Engine(mysql+mysqldb://root:***@localhost/foody)

# %%
def sql_to_df(sql_query):
    df = pd.read_sql(sql_query, con)
    return df

# %%
query='SELECT * FROM foody.client limit 5';
dd=sql_to_df(query)
dd
# Out:
#   codeclient                             societe             contact  \
# 0      ALFKI                 Alfreds Futterkiste        Maria Anders
# 1      ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2      ANTON              Antonio Moreno Taquera      Antonio Moreno
# 3      AROUT                     Around the Horn        Thomas Hardy
# 4      BERGS                   Berglunds snabbkp  Christina Berglund
#
#                fonction                       adresse       ville region  \
# 0  Sales Representative                 Obere Str. 57      Berlin   None
# 1                 Owner  Avda. de la Constitucin 2222  Mxico D.F.   None
# 2                 Owner               Mataderos  2312  Mxico D.F.   None
# 3  Sales Representative               120 Hanover Sq.      London   None
# 4   Order Administrator                Berguvsvgen  8        Lule   None
#
#   codepostal     pays             tel             fax
# 0      12209  Germany     030-0074321     030-0076545
# ...

# %%
query='SELECT * FROM foody.fournisseur limit 5';
dd=sql_to_df(query)
dd
# Out:
#    Nofour                             société                      contact  \
# 0       1                      Exotic Liquids             Charlotte Cooper
# 1       2          New Orleans Cajun Delights                Shelley Burke
# 2       3           Grandma Kelly's Homestead                Regina Murphy
# 3       4                       Tokyo Traders                 Yoshi Nagase
# 4       5  Cooperativa de Quesos 'Las Cabras'  Antonio del Valle Saavedra
#
#                fonction                     adresse        ville    region  \
# 0    Purchasing Manager              49 Gilbert St.       London      None
# 1   Order Administrator              P.O. Box 78934  New Orleans        LA
# 2  Sales Representative              707 Oxford Rd.    Ann Arbor        MI
# 3     Marketing Manager  9-8 Sekimai\nMusashino-shi        Tokyo      None
# 4  Export Administrator           Calle del Rosal 4       Oviedo  Asturias
#
#   codepostal   pays             tel             fax  pageacceuil
# ...
